# %% [markdown]
# # cross validation

# %% [markdown]
# ביצוע
# Cross Validation
# כדי לוודא
#  שהמודל לא מתאים את עצמו יתר על המידה לקבוצת אימון מסוימת,
#   אלא מסוגל להכליל על דאטה חדש.

# %%
# ==== Environment Setup ====
import os
import warnings
import copy
import time

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# ==== Core Python ====
import numpy as np
import pandas as pd

# ==== Visualization ====
import matplotlib.pyplot as plt
import seaborn as sns

# ==== PyTorch ====
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import AdamW

# ==== HuggingFace Transformers ====
from transformers import BertModel, BertTokenizerFast

# ==== Sklearn ====
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.utils.multiclass import unique_labels
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix
)

# %% [markdown]
# דאטה מורכב מ:
# 1. SLURP מתורגם מתאים לכוונות שלנו
# 2. דאטה סינטטי באמצעות פרומטים לCHAT-GPT
# 3. נתונים מהפיילוט בסמסטר א 3 צעירים וקשישה (סונן ל10 כוונות מתאימות)
# 4. מורכב מניסויים סופיים שביצענו בסמסטר ב - רק צעירים
#
# על דאטה זה מבוצע CROSS VALIDITION
# חלוקה ל train \ val
#
# הערכה סופית מבוצעת על דאטה של הקשישים שהפקנו מהניסויים סופיים בסמסטר ב

# %%
# Load datasets
train = pd.read_csv('/home/naamamai/Final_Project/train.csv')
elderly_with_label = pd.read_csv('/home/naamamai/Final_Project/elderly.csv')
young_with_label = pd.read_csv('/home/naamamai/Final_Project/young.csv')

# %%
# Check and remove duplicates in train
train_duplicates = train.duplicated().sum()
if train_duplicates > 0:
    print(f"Found {train_duplicates} duplicate rows in train.csv.")
    train = train.drop_duplicates()
else:
    print("No duplicate rows found in train.csv.")

# Check and remove duplicates in test
test_duplicates = elderly_with_label.duplicated().sum()
if test_duplicates > 0:
    print(f"Found {test_duplicates} duplicate rows in test.csv.")
    test_with_label = elderly_with_label.drop_duplicates()
else:
    print("No duplicate rows found in test.csv.")
# Out:
# Found 3884 duplicate rows in train.csv.
# Found 16 duplicate rows in test.csv.

# %%
# Create a new DataFrame without the 'label' column
elderly_without_label = elderly_with_label.drop(columns=['label'])
young_without_label = young_with_label.drop(columns=['label'])

data = pd.concat([train, young_without_label], ignore_index=True)

# %% [markdown]
# בדיקה האם צעירים אמרו משפטים כמעט זהים לאלו שהקשישים אמרו

# %%
train_texts = set(train["transcript_hebrew"])
elderly_texts = set(elderly_without_label["transcript_hebrew"])
overlap = elderly_texts.intersection(train_texts)
print(f"Found {len(overlap)} overlapping texts between elderly test and train data.")
# Out:
# Found 0 overlapping texts between elderly test and train data.

# %%
# Encode labels
le = LabelEncoder()
data['intent_num'] = le.fit_transform(data['intent'])
map_intent = dict(zip(le.transform(le.classes_), le.classes_))

map_intent
# Out:
# {0: 'alarm_set',
#  1: 'calendar_set',
#  2: 'call_contact',
#  3: 'camera_query',
#  4: 'iot_wemo_on',
#  5: 'lists_createoradd',
#  6: 'query',
#  7: 'send_message',
#  8: 'transport_query',
#  9: 'weather_query'}

# %%
X = data['transcript_hebrew'].values
y = data['intent_num'].values
X, y = shuffle(X, y, random_state=42)

# %%
# Load tokenizer and model
model_name = 'dicta-il/alephbertgimmel-base'
tokenizer = BertTokenizerFast.from_pretrained(model_name)
base_model = BertModel.from_pretrained(model_name)

# %%
# Model definition
class BertForIntentClassification(nn.Module):
    def __init__(self, bert_model, num_classes):
        super(BertForIntentClassification, self).__init__()
        self.bert = bert_model
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(bert_model.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)
        logits = self.classifier(cls_output)
        return logits

# %%
# Grid search
def plot_training_stats(train_losses, val_losses, train_accuracies, val_accuracies, lr, bs):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label="Training Loss")
    plt.plot(val_losses, label="Validation Loss")
    plt.title(f"Loss (LR={lr}, BS={bs})")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label="Training Accuracy")
    plt.plot(val_accuracies, label="Validation Accuracy")
    plt.title(f"Accuracy (LR={lr}, BS={bs})")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def plot_val_loss_summary(val_loss_dict):
    labels = list(val_loss_dict.keys())
    x = np.arange(len(val_loss_dict[labels[0]]))
    width = 0.2
    plt.figure(figsize=(10, 6))
    for i, bs in enumerate(val_loss_dict):
        plt.bar(x + i * width, val_loss_dict[bs], width, label=f'Batch Size: {bs}')
    plt.xticks(x + width, ['5e-05', '2e-05', '1e-05'])
    plt.xlabel('Learning Rates')
    plt.ylabel('Validation Loss')
    plt.title('Validation Loss Comparison')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def run_grid_search(encoded_inputs, labels, encoded_inputs_test, labels_test, map_intent, base_bert_model):
    best_lr = None
    learning_rates = [5e-5, 2e-5, 1e-5]
    batch_sizes = [16, 32, 64]
    num_classes = len(map_intent)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    best_val_loss = float('inf')
    best_model_path = "best_model_final.pt"
    best_bs = None
    best_cm = None
    best_used_names = None
    best_report = None
    best_report_time = 0
    best_acc = 0.0

    val_loss_summary = {bs: [] for bs in batch_sizes}

    for lr in learning_rates:
        for bs in batch_sizes:
            print(f"\n Training with LR={lr}, BS={bs}")
            start_time = time.time()
            model = BertForIntentClassification(copy.deepcopy(base_bert_model), num_classes).to(device)
            optimizer = AdamW(model.parameters(), lr=lr, weight_decay=1e-2)
            criterion = nn.CrossEntropyLoss()

            # Prepare train and test datasets
            train_dataset = TensorDataset(
                encoded_inputs['input_ids'].clone().detach(),
                encoded_inputs['attention_mask'].clone().detach(),
                torch.tensor(labels, dtype=torch.long)
            )
            test_dataset = TensorDataset(
                encoded_inputs_test['input_ids'].clone().detach(),
                encoded_inputs_test['attention_mask'].clone().detach(),
                torch.tensor(labels_test, dtype=torch.long)
            )

            train_loader = DataLoader(train_dataset, batch_size=bs, shuffle=True)
            test_loader = DataLoader(test_dataset, batch_size=bs, shuffle=False)

            best_loss = float('inf')
            early_stop_counter = 0
            patience = 3

            train_losses, val_losses = [], []
            train_accuracies, val_accuracies = [], []

            best_preds, best_labels = [], []

            for epoch in range(15):
                model.train()
                total_loss, correct_train, total_train = 0, 0, 0

                for batch in train_loader:
                    input_ids, attention_mask, y = [b.to(device) for b in batch]
                    optimizer.zero_grad()
                    outputs = model(input_ids, attention_mask)
                    loss = criterion(outputs, y)
                    loss.backward()
                    optimizer.step()

                    total_loss += loss.item()
                    preds = torch.argmax(outputs, dim=1)
                    correct_train += (preds == y).sum().item()
                    total_train += y.size(0)

                avg_train_loss = total_loss / len(train_loader)
                train_accuracy = correct_train / total_train

                model.eval()
                val_loss, correct_val, total_val = 0, 0, 0
                all_preds, all_labels = [], []

                with torch.no_grad():
                    for batch in test_loader:
                        input_ids, attention_mask, y = [b.to(device) for b in batch]
                        outputs = model(input_ids, attention_mask)
                        loss = criterion(outputs, y)
                        val_loss += loss.item()
                        preds = torch.argmax(outputs, dim=1)
                        correct_val += (preds == y).sum().item()
                        total_val += y.size(0)
                        all_preds.extend(preds.cpu().numpy())
                        all_labels.extend(y.cpu().numpy())

                avg_val_loss = val_loss / len(test_loader)
                val_accuracy = correct_val / total_val

                train_losses.append(avg_train_loss)
                val_losses.append(avg_val_loss)
                train_accuracies.append(train_accuracy)
                val_accuracies.append(val_accuracy)

                print(f"Epoch {epoch+1:>2}, Train Loss: {avg_train_loss:.4f}, Acc: {train_accuracy:.4f}, "
                      f"Val Loss: {avg_val_loss:.4f}, Acc: {val_accuracy:.4f}")

                # Save best model based on validation loss
                if avg_val_loss < best_loss:
                    best_loss = avg_val_loss
                    early_stop_counter = 0

                    if best_loss < best_val_loss:
                        best_val_loss = best_loss
                        torch.save(model.state_dict(), best_model_path)
                        best_bs = bs
                        best_lr = lr
                        best_preds = all_preds
                        best_labels = all_labels
                        best_used_names = [map_intent[i] for i in sorted(set(best_labels + best_preds))]
                        best_cm = confusion_matrix(best_labels, best_preds)
                        best_report = classification_report(best_labels, best_preds, target_names=best_used_names, digits=2)
                        best_report_time = time.time() - start_time
                        best_acc = accuracy_score(best_labels, best_preds)

                else:
                    early_stop_counter += 1

                if early_stop_counter >= patience:
                    print("Early stopping.")
                    break

            # Plot training and validation metrics
            plot_training_stats(
                train_losses,
                val_losses,
                train_accuracies,
                val_accuracies,
                lr,
                bs
            )

            val_loss_summary[bs].append(best_loss)

            print(f"\n Final Test Accuracy: {best_acc * 100:.2f}%")
            print("\n Classification Report:")
            print(best_report)
            print(f"\n Response Time: {best_report_time:.2f} seconds")

            del model
            torch.cuda.empty_cache()

    # Plot the best confusion matrix
    if best_cm is not None:
        plt.figure(figsize=(10, 8))
        sns.heatmap(best_cm, annot=True, fmt="d", cmap="Blues",
                    xticklabels=best_used_names,
                    yticklabels=best_used_names)
        plt.title("Best Confusion Matrix")
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.tight_layout()
        plt.show()

    # Plot validation loss across batch sizes
    plot_val_loss_summary(val_loss_summary)

    return best_model_path, best_bs, best_lr

# %%
def evaluate_best_model(encoded_inputs_test, labels_test, map_intent, base_bert_model, best_model_path, batch_size, return_metrics=False):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    test_dataset = TensorDataset(
        encoded_inputs_test['input_ids'].clone().detach(),
        encoded_inputs_test['attention_mask'].clone().detach(),
        torch.tensor(labels_test, dtype=torch.long)
    )
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    best_model = BertForIntentClassification(copy.deepcopy(base_bert_model), len(map_intent)).to(device)
    best_model.load_state_dict(torch.load(best_model_path))
    best_model.eval()

    predictions, true_labels = [], []
    with torch.no_grad():
        for batch in test_loader:
            input_ids, attention_mask, y = [b.to(device) for b in batch]
            outputs = best_model(input_ids, attention_mask)
            preds = torch.argmax(outputs, dim=1)
            predictions.extend(preds.cpu().numpy())
            true_labels.extend(y.cpu().numpy())

    acc = accuracy_score(true_labels, predictions)
    f1 = f1_score(true_labels, predictions, average='macro')
    report = classification_report(true_labels, predictions, target_names=[map_intent[i] for i in sorted(map_intent)], output_dict=True)

    if return_metrics:
        return acc, f1, report
    else:
        print(f"\n Final Accuracy: {acc * 100:.2f}%")
        print("\n Classification Report:")
        print(classification_report(true_labels, predictions, target_names=[map_intent[i] for i in sorted(map_intent)]))

# %%
results = []
best_f1 = 0.0
best_model_overall = None
best_model_path_overall = ""
best_batch_size_overall = None

k = 5
skf = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)
fold = 1

for train_idx, val_idx in skf.split(X, y):
    print(f"\n========== Fold {fold} ==========")
    X_train_texts, X_val_texts = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    encoded_train = tokenizer(
        list(X_train_texts), padding=True, truncation=True, max_length=128,
        return_tensors='pt'
    )
    encoded_val = tokenizer(
        list(X_val_texts), padding=True, truncation=True, max_length=128,
        return_tensors='pt'
    )

    encoded_inputs_fold = {
        'input_ids': encoded_train['input_ids'],
        'attention_mask': encoded_train['attention_mask']
    }
    encoded_inputs_val_fold = {
        'input_ids': encoded_val['input_ids'],
        'attention_mask': encoded_val['attention_mask']
    }

    # Train using grid search
    best_model_path, best_batch_size, best_learning_rate  = run_grid_search(
        encoded_inputs_fold,
        y_train,
        encoded_inputs_val_fold,
        y_val,
        map_intent,
        base_model
    )

    # Evaluate model
    acc, f1, report_dict = evaluate_best_model(
        encoded_inputs_val_fold,
        y_val,
        map_intent,
        base_model,
        best_model_path,
        best_batch_size,
        return_metrics=True  # Make sure this function returns metrics
    )

    # Store results
    results.append({
        'fold': fold,
        'accuracy': acc,
        'macro_f1': f1,
        'model_path': best_model_path,
        'batch_size': best_batch_size,
        'learning_rate': best_learning_rate


    })

    # Update best model if this one is better
    if f1 > best_f1:
        best_f1 = f1
        best_model_overall = base_model
        best_model_path_overall = best_model_path
        best_batch_size_overall = best_batch_size

    fold += 1

# Export summary CSV
results_df = pd.DataFrame(results)
results_df.to_csv("cross_validation_results.csv", index=False)

# === Performance Summary Across Folds ===
mean_f1 = results_df['macro_f1'].mean()
std_f1 = results_df['macro_f1'].std()

mean_acc = results_df['accuracy'].mean()
std_acc = results_df['accuracy'].std()

print("\n📊 Cross-Validation Performance Summary:")
print(f"Mean Macro F1: {mean_f1:.4f} ± {std_f1:.4f}")
print(f"Mean Accuracy: {mean_acc:.4f} ± {std_acc:.4f}")
# Out:
# ========== Fold 1 ==========
#
#  Training with LR=5e-05, BS=16
# Epoch  1, Train Loss: 0.4958, Acc: 0.8794, Val Loss: 0.0668, Acc: 0.9834
# Epoch  2, Train Loss: 0.0270, Acc: 0.9946, Val Loss: 0.0398, Acc: 0.9917
# Epoch  3, Train Loss: 0.0125, Acc: 0.9983, Val Loss: 0.0360, Acc: 0.9901
# Epoch  4, Train Loss: 0.0070, Acc: 0.9992, Val Loss: 0.0757, Acc: 0.9851
# Epoch  5, Train Loss: 0.0034, Acc: 1.0000, Val Loss: 0.0408, Acc: 0.9901
# Epoch  6, Train Loss: 0.0020, Acc: 1.0000, Val Loss: 0.0472, Acc: 0.9901
# Early stopping.
#  Final Test Accuracy: 99.01%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      0.98      0.98        43
#      calendar_set       0.97      0.99      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.97      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      0.99      0.99        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 24.11 seconds
#
#  Training with LR=5e-05, BS=32
# Epoch  1, Train Loss: 0.7040, Acc: 0.8119, Val Loss: 0.0642, Acc: 0.9868
# Epoch  2, Train Loss: 0.0448, Acc: 0.9938, Val Loss: 0.0324, Acc: 0.9934
# Epoch  3, Train Loss: 0.0149, Acc: 0.9992, Val Loss: 0.0327, Acc: 0.9917
# Epoch  4, Train Loss: 0.0072, Acc: 0.9996, Val Loss: 0.0288, Acc: 0.9917
# Epoch  5, Train Loss: 0.0044, Acc: 1.0000, Val Loss: 0.0299, Acc: 0.9917
# Epoch  6, Train Loss: 0.0034, Acc: 1.0000, Val Loss: 0.0296, Acc: 0.9917
# Epoch  7, Train Loss: 0.0026, Acc: 1.0000, Val Loss: 0.0298, Acc: 0.9901
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.98      0.99      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.96      0.96      0.96        28
#       iot_wemo_on       0.97      0.97      0.97        34
# lists_createoradd       1.00      0.97      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       1.00      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 20.74 seconds
#
#  Training with LR=5e-05, BS=64
# Epoch  1, Train Loss: 0.9879, Acc: 0.7323, Val Loss: 0.1646, Acc: 0.9785
# Epoch  2, Train Loss: 0.0926, Acc: 0.9884, Val Loss: 0.0544, Acc: 0.9884
# Epoch  3, Train Loss: 0.0263, Acc: 0.9979, Val Loss: 0.0359, Acc: 0.9917
# Epoch  4, Train Loss: 0.0132, Acc: 0.9992, Val Loss: 0.0375, Acc: 0.9851
# Epoch  5, Train Loss: 0.0089, Acc: 0.9996, Val Loss: 0.0349, Acc: 0.9934
# Epoch  6, Train Loss: 0.0059, Acc: 1.0000, Val Loss: 0.0361, Acc: 0.9901
# Epoch  7, Train Loss: 0.0047, Acc: 1.0000, Val Loss: 0.0410, Acc: 0.9901
# Epoch  8, Train Loss: 0.0035, Acc: 1.0000, Val Loss: 0.0359, Acc: 0.9884
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.98      0.99      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.96      0.96      0.96        28
#       iot_wemo_on       0.97      0.97      0.97        34
# lists_createoradd       1.00      0.97      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       1.00      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 20.74 seconds
#
#  Training with LR=2e-05, BS=16
# Epoch  1, Train Loss: 0.9657, Acc: 0.7576, Val Loss: 0.1478, Acc: 0.9818
# Epoch  2, Train Loss: 0.0984, Acc: 0.9892, Val Loss: 0.0509, Acc: 0.9917
# Epoch  3, Train Loss: 0.0343, Acc: 0.9971, Val Loss: 0.0433, Acc: 0.9917
# Epoch  4, Train Loss: 0.0179, Acc: 0.9992, Val Loss: 0.0343, Acc: 0.9851
# Epoch  5, Train Loss: 0.0097, Acc: 1.0000, Val Loss: 0.0329, Acc: 0.9884
# Epoch  6, Train Loss: 0.0065, Acc: 1.0000, Val Loss: 0.0312, Acc: 0.9868
# Epoch  7, Train Loss: 0.0048, Acc: 1.0000, Val Loss: 0.0286, Acc: 0.9934
# Epoch  8, Train Loss: 0.0039, Acc: 1.0000, Val Loss: 0.0308, Acc: 0.9917
# Epoch  9, Train Loss: 0.0031, Acc: 1.0000, Val Loss: 0.0315, Acc: 0.9901
# Epoch 10, Train Loss: 0.0026, Acc: 1.0000, Val Loss: 0.0295, Acc: 0.9901
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
#
#  Training with LR=2e-05, BS=32
# Epoch  1, Train Loss: 1.3160, Acc: 0.6361, Val Loss: 0.3763, Acc: 0.9570
# Epoch  2, Train Loss: 0.2298, Acc: 0.9755, Val Loss: 0.0918, Acc: 0.9834
# Epoch  3, Train Loss: 0.0707, Acc: 0.9942, Val Loss: 0.0523, Acc: 0.9884
# Epoch  4, Train Loss: 0.0360, Acc: 0.9983, Val Loss: 0.0410, Acc: 0.9884
# Epoch  5, Train Loss: 0.0211, Acc: 0.9988, Val Loss: 0.0351, Acc: 0.9934
# Epoch  6, Train Loss: 0.0132, Acc: 0.9996, Val Loss: 0.0355, Acc: 0.9901
# Epoch  7, Train Loss: 0.0098, Acc: 0.9996, Val Loss: 0.0379, Acc: 0.9901
# Epoch  8, Train Loss: 0.0079, Acc: 1.0000, Val Loss: 0.0334, Acc: 0.9901
# Epoch  9, Train Loss: 0.0062, Acc: 1.0000, Val Loss: 0.0383, Acc: 0.9917
# Epoch 10, Train Loss: 0.0051, Acc: 1.0000, Val Loss: 0.0389, Acc: 0.9901
# Epoch 11, Train Loss: 0.0042, Acc: 1.0000, Val Loss: 0.0378, Acc: 0.9917
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
#
#  Training with LR=2e-05, BS=64
# Epoch  1, Train Loss: 1.7568, Acc: 0.4244, Val Loss: 0.9988, Acc: 0.8212
# Epoch  2, Train Loss: 0.6504, Acc: 0.9034, Val Loss: 0.2661, Acc: 0.9652
# Epoch  3, Train Loss: 0.1988, Acc: 0.9847, Val Loss: 0.1042, Acc: 0.9801
# Epoch  4, Train Loss: 0.0831, Acc: 0.9942, Val Loss: 0.0668, Acc: 0.9834
# Epoch  5, Train Loss: 0.0461, Acc: 0.9967, Val Loss: 0.0504, Acc: 0.9868
# Epoch  6, Train Loss: 0.0309, Acc: 0.9983, Val Loss: 0.0467, Acc: 0.9851
# Epoch  7, Train Loss: 0.0203, Acc: 0.9992, Val Loss: 0.0421, Acc: 0.9868
# Epoch  8, Train Loss: 0.0164, Acc: 0.9996, Val Loss: 0.0405, Acc: 0.9868
# Epoch  9, Train Loss: 0.0130, Acc: 0.9996, Val Loss: 0.0407, Acc: 0.9868
# Epoch 10, Train Loss: 0.0103, Acc: 0.9996, Val Loss: 0.0382, Acc: 0.9884
# Epoch 11, Train Loss: 0.0087, Acc: 0.9996, Val Loss: 0.0390, Acc: 0.9868
# Epoch 12, Train Loss: 0.0072, Acc: 1.0000, Val Loss: 0.0382, Acc: 0.9868
# Epoch 13, Train Loss: 0.0063, Acc: 1.0000, Val Loss: 0.0375, Acc: 0.9884
# Epoch 14, Train Loss: 0.0055, Acc: 1.0000, Val Loss: 0.0357, Acc: 0.9884
# Epoch 15, Train Loss: 0.0050, Acc: 1.0000, Val Loss: 0.0366, Acc: 0.9868
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
#
#  Training with LR=1e-05, BS=16
# Epoch  1, Train Loss: 1.4057, Acc: 0.6191, Val Loss: 0.5281, Acc: 0.9454
# Epoch  2, Train Loss: 0.3375, Acc: 0.9631, Val Loss: 0.1398, Acc: 0.9834
# Epoch  3, Train Loss: 0.1139, Acc: 0.9913, Val Loss: 0.0775, Acc: 0.9851
# Epoch  4, Train Loss: 0.0576, Acc: 0.9946, Val Loss: 0.0490, Acc: 0.9884
# Epoch  5, Train Loss: 0.0338, Acc: 0.9983, Val Loss: 0.0464, Acc: 0.9851
# Epoch  6, Train Loss: 0.0212, Acc: 0.9988, Val Loss: 0.0434, Acc: 0.9901
# Epoch  7, Train Loss: 0.0160, Acc: 0.9992, Val Loss: 0.0450, Acc: 0.9901
# Epoch  8, Train Loss: 0.0120, Acc: 0.9992, Val Loss: 0.0426, Acc: 0.9884
# Epoch  9, Train Loss: 0.0094, Acc: 0.9996, Val Loss: 0.0427, Acc: 0.9901
# Epoch 10, Train Loss: 0.0076, Acc: 1.0000, Val Loss: 0.0431, Acc: 0.9901
# Epoch 11, Train Loss: 0.0061, Acc: 1.0000, Val Loss: 0.0397, Acc: 0.9901
# Epoch 12, Train Loss: 0.0051, Acc: 1.0000, Val Loss: 0.0433, Acc: 0.9901
# Epoch 13, Train Loss: 0.0045, Acc: 1.0000, Val Loss: 0.0436, Acc: 0.9901
# Epoch 14, Train Loss: 0.0039, Acc: 1.0000, Val Loss: 0.0442, Acc: 0.9901
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
#
#  Training with LR=1e-05, BS=32
# Epoch  1, Train Loss: 1.8231, Acc: 0.4090, Val Loss: 1.1020, Acc: 0.8262
# Epoch  2, Train Loss: 0.7680, Acc: 0.8877, Val Loss: 0.3785, Acc: 0.9570
# Epoch  3, Train Loss: 0.2994, Acc: 0.9693, Val Loss: 0.1585, Acc: 0.9752
# Epoch  4, Train Loss: 0.1414, Acc: 0.9925, Val Loss: 0.0914, Acc: 0.9818
# Epoch  5, Train Loss: 0.0819, Acc: 0.9954, Val Loss: 0.0634, Acc: 0.9851
# Epoch  6, Train Loss: 0.0505, Acc: 0.9983, Val Loss: 0.0513, Acc: 0.9868
# Epoch  7, Train Loss: 0.0365, Acc: 0.9979, Val Loss: 0.0445, Acc: 0.9868
# Epoch  8, Train Loss: 0.0274, Acc: 0.9988, Val Loss: 0.0431, Acc: 0.9834
# Epoch  9, Train Loss: 0.0200, Acc: 0.9992, Val Loss: 0.0421, Acc: 0.9868
# Epoch 10, Train Loss: 0.0169, Acc: 0.9992, Val Loss: 0.0439, Acc: 0.9868
# Epoch 11, Train Loss: 0.0136, Acc: 0.9992, Val Loss: 0.0414, Acc: 0.9868
# Epoch 12, Train Loss: 0.0112, Acc: 0.9996, Val Loss: 0.0430, Acc: 0.9868
# Epoch 13, Train Loss: 0.0101, Acc: 0.9996, Val Loss: 0.0396, Acc: 0.9884
# Epoch 14, Train Loss: 0.0085, Acc: 1.0000, Val Loss: 0.0387, Acc: 0.9884
# Epoch 15, Train Loss: 0.0074, Acc: 1.0000, Val Loss: 0.0408, Acc: 0.9868
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
#
#  Training with LR=1e-05, BS=64
# Epoch  1, Train Loss: 1.9794, Acc: 0.3398, Val Loss: 1.5329, Acc: 0.5464
# Epoch  2, Train Loss: 1.2590, Acc: 0.7149, Val Loss: 0.8357, Acc: 0.8841
# Epoch  3, Train Loss: 0.6782, Acc: 0.9163, Val Loss: 0.3977, Acc: 0.9619
# Epoch  4, Train Loss: 0.3548, Acc: 0.9660, Val Loss: 0.2057, Acc: 0.9719
# Epoch  5, Train Loss: 0.2033, Acc: 0.9834, Val Loss: 0.1263, Acc: 0.9752
# Epoch  6, Train Loss: 0.1257, Acc: 0.9913, Val Loss: 0.0868, Acc: 0.9834
# Epoch  7, Train Loss: 0.0816, Acc: 0.9963, Val Loss: 0.0666, Acc: 0.9868
# Epoch  8, Train Loss: 0.0614, Acc: 0.9954, Val Loss: 0.0568, Acc: 0.9884
# Epoch  9, Train Loss: 0.0467, Acc: 0.9979, Val Loss: 0.0482, Acc: 0.9917
# Epoch 10, Train Loss: 0.0376, Acc: 0.9983, Val Loss: 0.0449, Acc: 0.9917
# Epoch 11, Train Loss: 0.0303, Acc: 0.9983, Val Loss: 0.0418, Acc: 0.9901
# Epoch 12, Train Loss: 0.0253, Acc: 0.9988, Val Loss: 0.0389, Acc: 0.9917
# Epoch 13, Train Loss: 0.0212, Acc: 0.9992, Val Loss: 0.0375, Acc: 0.9917
# Epoch 14, Train Loss: 0.0184, Acc: 0.9996, Val Loss: 0.0367, Acc: 0.9901
# Epoch 15, Train Loss: 0.0158, Acc: 0.9992, Val Loss: 0.0369, Acc: 0.9901
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       0.98      1.00      0.99        43
#      calendar_set       0.99      0.98      0.98        89
#      call_contact       1.00      1.00      1.00        32
#      camera_query       0.97      1.00      0.98        28
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       1.00      0.98      0.99        62
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        32
#   transport_query       1.00      1.00      1.00        93
#     weather_query       0.99      1.00      1.00       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 50.28 seconds
# /tmp/ipykernel_1039963/1756765122.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load(best_model_path))
# ========== Fold 2 ==========
#
#  Training with LR=5e-05, BS=16
# Epoch  1, Train Loss: 0.5015, Acc: 0.8753, Val Loss: 0.0479, Acc: 0.9884
# Epoch  2, Train Loss: 0.0308, Acc: 0.9963, Val Loss: 0.0440, Acc: 0.9868
# Epoch  3, Train Loss: 0.0129, Acc: 0.9983, Val Loss: 0.0304, Acc: 0.9901
# Epoch  4, Train Loss: 0.0048, Acc: 1.0000, Val Loss: 0.0282, Acc: 0.9901
# Epoch  5, Train Loss: 0.0076, Acc: 0.9992, Val Loss: 0.0251, Acc: 0.9917
# Epoch  6, Train Loss: 0.0045, Acc: 0.9996, Val Loss: 0.0261, Acc: 0.9917
# Epoch  7, Train Loss: 0.0070, Acc: 0.9979, Val Loss: 0.1406, Acc: 0.9685
# Epoch  8, Train Loss: 0.0219, Acc: 0.9942, Val Loss: 0.0508, Acc: 0.9818
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=5e-05, BS=32
# Epoch  1, Train Loss: 0.7441, Acc: 0.8036, Val Loss: 0.0928, Acc: 0.9752
# Epoch  2, Train Loss: 0.0539, Acc: 0.9905, Val Loss: 0.0467, Acc: 0.9851
# Epoch  3, Train Loss: 0.0156, Acc: 0.9988, Val Loss: 0.0430, Acc: 0.9868
# Epoch  4, Train Loss: 0.0083, Acc: 0.9996, Val Loss: 0.0502, Acc: 0.9851
# Epoch  5, Train Loss: 0.0071, Acc: 0.9996, Val Loss: 0.0351, Acc: 0.9901
# Epoch  6, Train Loss: 0.0089, Acc: 0.9992, Val Loss: 0.0344, Acc: 0.9901
# Epoch  7, Train Loss: 0.0034, Acc: 0.9996, Val Loss: 0.0386, Acc: 0.9901
# Epoch  8, Train Loss: 0.0030, Acc: 1.0000, Val Loss: 0.0400, Acc: 0.9884
# Epoch  9, Train Loss: 0.0020, Acc: 1.0000, Val Loss: 0.0465, Acc: 0.9884
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=5e-05, BS=64
# Epoch  1, Train Loss: 1.0544, Acc: 0.7248, Val Loss: 0.1831, Acc: 0.9652
# Epoch  2, Train Loss: 0.1008, Acc: 0.9863, Val Loss: 0.0581, Acc: 0.9851
# Epoch  3, Train Loss: 0.0293, Acc: 0.9979, Val Loss: 0.0480, Acc: 0.9851
# Epoch  4, Train Loss: 0.0146, Acc: 0.9992, Val Loss: 0.0508, Acc: 0.9834
# Epoch  5, Train Loss: 0.0094, Acc: 0.9996, Val Loss: 0.0470, Acc: 0.9868
# Epoch  6, Train Loss: 0.0072, Acc: 0.9992, Val Loss: 0.0456, Acc: 0.9868
# Epoch  7, Train Loss: 0.0053, Acc: 1.0000, Val Loss: 0.0457, Acc: 0.9868
# Epoch  8, Train Loss: 0.0042, Acc: 1.0000, Val Loss: 0.0466, Acc: 0.9834
# Epoch  9, Train Loss: 0.0032, Acc: 1.0000, Val Loss: 0.0440, Acc: 0.9851
# Epoch 10, Train Loss: 0.0027, Acc: 1.0000, Val Loss: 0.0458, Acc: 0.9868
# Epoch 11, Train Loss: 0.0024, Acc: 1.0000, Val Loss: 0.0475, Acc: 0.9851
# Epoch 12, Train Loss: 0.0021, Acc: 1.0000, Val Loss: 0.0493, Acc: 0.9851
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=2e-05, BS=16
# Epoch  1, Train Loss: 1.0453, Acc: 0.7261, Val Loss: 0.1869, Acc: 0.9818
# Epoch  2, Train Loss: 0.1165, Acc: 0.9896, Val Loss: 0.0641, Acc: 0.9868
# Epoch  3, Train Loss: 0.0391, Acc: 0.9959, Val Loss: 0.0454, Acc: 0.9868
# Epoch  4, Train Loss: 0.0189, Acc: 0.9983, Val Loss: 0.0398, Acc: 0.9868
# Epoch  5, Train Loss: 0.0144, Acc: 0.9983, Val Loss: 0.0414, Acc: 0.9851
# Epoch  6, Train Loss: 0.0092, Acc: 0.9996, Val Loss: 0.0372, Acc: 0.9868
# Epoch  7, Train Loss: 0.0054, Acc: 1.0000, Val Loss: 0.0375, Acc: 0.9851
# Epoch  8, Train Loss: 0.0043, Acc: 1.0000, Val Loss: 0.0396, Acc: 0.9851
# Epoch  9, Train Loss: 0.0035, Acc: 1.0000, Val Loss: 0.0398, Acc: 0.9851
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=2e-05, BS=32
# Epoch  1, Train Loss: 1.3575, Acc: 0.6200, Val Loss: 0.4134, Acc: 0.9454
# Epoch  2, Train Loss: 0.2372, Acc: 0.9805, Val Loss: 0.0926, Acc: 0.9851
# Epoch  3, Train Loss: 0.0675, Acc: 0.9959, Val Loss: 0.0640, Acc: 0.9851
# Epoch  4, Train Loss: 0.0315, Acc: 0.9983, Val Loss: 0.0473, Acc: 0.9868
# Epoch  5, Train Loss: 0.0220, Acc: 0.9971, Val Loss: 0.0464, Acc: 0.9851
# Epoch  6, Train Loss: 0.0147, Acc: 0.9988, Val Loss: 0.0451, Acc: 0.9901
# Epoch  7, Train Loss: 0.0101, Acc: 1.0000, Val Loss: 0.0392, Acc: 0.9901
# Epoch  8, Train Loss: 0.0077, Acc: 1.0000, Val Loss: 0.0395, Acc: 0.9917
# Epoch  9, Train Loss: 0.0103, Acc: 0.9988, Val Loss: 0.0433, Acc: 0.9868
# Epoch 10, Train Loss: 0.0094, Acc: 0.9988, Val Loss: 0.0353, Acc: 0.9917
# Epoch 11, Train Loss: 0.0047, Acc: 1.0000, Val Loss: 0.0308, Acc: 0.9917
# Epoch 12, Train Loss: 0.0041, Acc: 1.0000, Val Loss: 0.0413, Acc: 0.9884
# Epoch 13, Train Loss: 0.0038, Acc: 1.0000, Val Loss: 0.0327, Acc: 0.9884
# Epoch 14, Train Loss: 0.0030, Acc: 1.0000, Val Loss: 0.0304, Acc: 0.9901
# Epoch 15, Train Loss: 0.0026, Acc: 1.0000, Val Loss: 0.0326, Acc: 0.9901
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=2e-05, BS=64
# Epoch  1, Train Loss: 1.7105, Acc: 0.4554, Val Loss: 0.9504, Acc: 0.8377
# Epoch  2, Train Loss: 0.6251, Acc: 0.9159, Val Loss: 0.2574, Acc: 0.9636
# Epoch  3, Train Loss: 0.1992, Acc: 0.9814, Val Loss: 0.1054, Acc: 0.9785
# Epoch  4, Train Loss: 0.0865, Acc: 0.9934, Val Loss: 0.0719, Acc: 0.9851
# Epoch  5, Train Loss: 0.0490, Acc: 0.9967, Val Loss: 0.0600, Acc: 0.9851
# Epoch  6, Train Loss: 0.0336, Acc: 0.9975, Val Loss: 0.0432, Acc: 0.9901
# Epoch  7, Train Loss: 0.0246, Acc: 0.9975, Val Loss: 0.0456, Acc: 0.9884
# Epoch  8, Train Loss: 0.0180, Acc: 0.9983, Val Loss: 0.0441, Acc: 0.9868
# Epoch  9, Train Loss: 0.0149, Acc: 0.9983, Val Loss: 0.0389, Acc: 0.9884
# Epoch 10, Train Loss: 0.0140, Acc: 0.9983, Val Loss: 0.0401, Acc: 0.9884
# Epoch 11, Train Loss: 0.0097, Acc: 0.9996, Val Loss: 0.0418, Acc: 0.9884
# Epoch 12, Train Loss: 0.0081, Acc: 1.0000, Val Loss: 0.0426, Acc: 0.9868
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=1e-05, BS=16
# Epoch  1, Train Loss: 1.5598, Acc: 0.5325, Val Loss: 0.6126, Acc: 0.9387
# Epoch  2, Train Loss: 0.3766, Acc: 0.9639, Val Loss: 0.1536, Acc: 0.9785
# Epoch  3, Train Loss: 0.1178, Acc: 0.9917, Val Loss: 0.0760, Acc: 0.9851
# Epoch  4, Train Loss: 0.0566, Acc: 0.9954, Val Loss: 0.0608, Acc: 0.9851
# Epoch  5, Train Loss: 0.0358, Acc: 0.9963, Val Loss: 0.0472, Acc: 0.9884
# Epoch  6, Train Loss: 0.0237, Acc: 0.9983, Val Loss: 0.0565, Acc: 0.9834
# Epoch  7, Train Loss: 0.0169, Acc: 0.9992, Val Loss: 0.0435, Acc: 0.9884
# Epoch  8, Train Loss: 0.0120, Acc: 1.0000, Val Loss: 0.0403, Acc: 0.9901
# Epoch  9, Train Loss: 0.0096, Acc: 0.9996, Val Loss: 0.0431, Acc: 0.9884
# Epoch 10, Train Loss: 0.0077, Acc: 1.0000, Val Loss: 0.0411, Acc: 0.9884
# Epoch 11, Train Loss: 0.0065, Acc: 1.0000, Val Loss: 0.0403, Acc: 0.9884
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=1e-05, BS=32
# Epoch  1, Train Loss: 1.8012, Acc: 0.4248, Val Loss: 1.0219, Acc: 0.8576
# Epoch  2, Train Loss: 0.7158, Acc: 0.9076, Val Loss: 0.3361, Acc: 0.9603
# Epoch  3, Train Loss: 0.2736, Acc: 0.9714, Val Loss: 0.1477, Acc: 0.9851
# Epoch  4, Train Loss: 0.1276, Acc: 0.9917, Val Loss: 0.0882, Acc: 0.9884
# Epoch  5, Train Loss: 0.0722, Acc: 0.9934, Val Loss: 0.0677, Acc: 0.9901
# Epoch  6, Train Loss: 0.0465, Acc: 0.9967, Val Loss: 0.0583, Acc: 0.9901
# Epoch  7, Train Loss: 0.0338, Acc: 0.9979, Val Loss: 0.0513, Acc: 0.9884
# Epoch  8, Train Loss: 0.0254, Acc: 0.9983, Val Loss: 0.0452, Acc: 0.9884
# Epoch  9, Train Loss: 0.0191, Acc: 0.9992, Val Loss: 0.0456, Acc: 0.9868
# Epoch 10, Train Loss: 0.0151, Acc: 0.9992, Val Loss: 0.0427, Acc: 0.9884
# Epoch 11, Train Loss: 0.0120, Acc: 1.0000, Val Loss: 0.0422, Acc: 0.9884
# Epoch 12, Train Loss: 0.0105, Acc: 1.0000, Val Loss: 0.0448, Acc: 0.9868
# Epoch 13, Train Loss: 0.0096, Acc: 1.0000, Val Loss: 0.0445, Acc: 0.9884
# Epoch 14, Train Loss: 0.0079, Acc: 1.0000, Val Loss: 0.0437, Acc: 0.9884
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
#
#  Training with LR=1e-05, BS=64
# Epoch  1, Train Loss: 2.0019, Acc: 0.2967, Val Loss: 1.5626, Acc: 0.5596
# Epoch  2, Train Loss: 1.3333, Acc: 0.6676, Val Loss: 0.8897, Acc: 0.8377
# Epoch  3, Train Loss: 0.7548, Acc: 0.8823, Val Loss: 0.4447, Acc: 0.9553
# Epoch  4, Train Loss: 0.4038, Acc: 0.9552, Val Loss: 0.2362, Acc: 0.9735
# Epoch  5, Train Loss: 0.2296, Acc: 0.9789, Val Loss: 0.1444, Acc: 0.9768
# Epoch  6, Train Loss: 0.1373, Acc: 0.9930, Val Loss: 0.1026, Acc: 0.9785
# Epoch  7, Train Loss: 0.0930, Acc: 0.9942, Val Loss: 0.0814, Acc: 0.9801
# Epoch  8, Train Loss: 0.0705, Acc: 0.9954, Val Loss: 0.0677, Acc: 0.9785
# Epoch  9, Train Loss: 0.0515, Acc: 0.9979, Val Loss: 0.0616, Acc: 0.9818
# Epoch 10, Train Loss: 0.0426, Acc: 0.9975, Val Loss: 0.0558, Acc: 0.9851
# Epoch 11, Train Loss: 0.0348, Acc: 0.9975, Val Loss: 0.0544, Acc: 0.9834
# Epoch 12, Train Loss: 0.0274, Acc: 0.9983, Val Loss: 0.0527, Acc: 0.9868
# Epoch 13, Train Loss: 0.0233, Acc: 0.9988, Val Loss: 0.0493, Acc: 0.9851
# Epoch 14, Train Loss: 0.0201, Acc: 0.9988, Val Loss: 0.0479, Acc: 0.9868
# Epoch 15, Train Loss: 0.0177, Acc: 0.9992, Val Loss: 0.0491, Acc: 0.9851
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        43
#      calendar_set       0.99      0.99      0.99        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      0.96      0.98        28
#       iot_wemo_on       0.97      1.00      0.99        33
# lists_createoradd       0.97      1.00      0.98        61
#             query       1.00      1.00      1.00        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       0.99      0.99      0.99        93
#     weather_query       1.00      0.98      0.99       123
#
#          accuracy                           0.99       604
#         macro avg       0.99      0.99      0.99       604
#      weighted avg       0.99      0.99      0.99       604
#
#
#  Response Time: 40.67 seconds
# /tmp/ipykernel_1039963/1756765122.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load(best_model_path))
# ========== Fold 3 ==========
#
#  Training with LR=5e-05, BS=16
# Epoch  1, Train Loss: 0.5427, Acc: 0.8534, Val Loss: 0.0486, Acc: 0.9884
# Epoch  2, Train Loss: 0.0368, Acc: 0.9950, Val Loss: 0.0254, Acc: 0.9900
# Epoch  3, Train Loss: 0.0104, Acc: 0.9996, Val Loss: 0.0233, Acc: 0.9934
# Epoch  4, Train Loss: 0.0062, Acc: 0.9992, Val Loss: 0.0228, Acc: 0.9934
# Epoch  5, Train Loss: 0.0050, Acc: 0.9992, Val Loss: 0.0303, Acc: 0.9917
# Epoch  6, Train Loss: 0.0056, Acc: 0.9992, Val Loss: 0.0259, Acc: 0.9917
# Epoch  7, Train Loss: 0.0017, Acc: 1.0000, Val Loss: 0.0274, Acc: 0.9917
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=5e-05, BS=32
# Epoch  1, Train Loss: 0.7462, Acc: 0.8115, Val Loss: 0.0694, Acc: 0.9884
# Epoch  2, Train Loss: 0.0505, Acc: 0.9934, Val Loss: 0.0391, Acc: 0.9884
# Epoch  3, Train Loss: 0.0218, Acc: 0.9967, Val Loss: 0.0347, Acc: 0.9934
# Epoch  4, Train Loss: 0.0116, Acc: 0.9992, Val Loss: 0.0343, Acc: 0.9934
# Epoch  5, Train Loss: 0.0079, Acc: 0.9996, Val Loss: 0.0344, Acc: 0.9934
# Epoch  6, Train Loss: 0.0047, Acc: 0.9996, Val Loss: 0.0348, Acc: 0.9934
# Epoch  7, Train Loss: 0.0031, Acc: 1.0000, Val Loss: 0.0354, Acc: 0.9934
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=5e-05, BS=64
# Epoch  1, Train Loss: 1.0874, Acc: 0.7067, Val Loss: 0.1711, Acc: 0.9801
# Epoch  2, Train Loss: 0.0978, Acc: 0.9892, Val Loss: 0.0480, Acc: 0.9917
# Epoch  3, Train Loss: 0.0307, Acc: 0.9979, Val Loss: 0.0344, Acc: 0.9950
# Epoch  4, Train Loss: 0.0157, Acc: 0.9992, Val Loss: 0.0365, Acc: 0.9917
# Epoch  5, Train Loss: 0.0111, Acc: 0.9983, Val Loss: 0.0292, Acc: 0.9934
# Epoch  6, Train Loss: 0.0063, Acc: 1.0000, Val Loss: 0.0383, Acc: 0.9917
# Epoch  7, Train Loss: 0.0055, Acc: 1.0000, Val Loss: 0.0360, Acc: 0.9900
# Epoch  8, Train Loss: 0.0040, Acc: 1.0000, Val Loss: 0.0338, Acc: 0.9917
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=2e-05, BS=16
# Epoch  1, Train Loss: 0.9938, Acc: 0.7386, Val Loss: 0.1676, Acc: 0.9851
# Epoch  2, Train Loss: 0.1043, Acc: 0.9905, Val Loss: 0.0456, Acc: 0.9900
# Epoch  3, Train Loss: 0.0365, Acc: 0.9967, Val Loss: 0.0332, Acc: 0.9900
# Epoch  4, Train Loss: 0.0160, Acc: 0.9996, Val Loss: 0.0254, Acc: 0.9934
# Epoch  5, Train Loss: 0.0111, Acc: 0.9992, Val Loss: 0.0256, Acc: 0.9934
# Epoch  6, Train Loss: 0.0120, Acc: 0.9983, Val Loss: 0.0258, Acc: 0.9917
# Epoch  7, Train Loss: 0.0054, Acc: 1.0000, Val Loss: 0.0252, Acc: 0.9934
# Epoch  8, Train Loss: 0.0040, Acc: 1.0000, Val Loss: 0.0279, Acc: 0.9934
# Epoch  9, Train Loss: 0.0032, Acc: 1.0000, Val Loss: 0.0296, Acc: 0.9934
# Epoch 10, Train Loss: 0.0027, Acc: 1.0000, Val Loss: 0.0292, Acc: 0.9934
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=2e-05, BS=32
# Epoch  1, Train Loss: 1.2441, Acc: 0.6719, Val Loss: 0.3381, Acc: 0.9652
# Epoch  2, Train Loss: 0.2011, Acc: 0.9826, Val Loss: 0.0741, Acc: 0.9934
# Epoch  3, Train Loss: 0.0668, Acc: 0.9946, Val Loss: 0.0459, Acc: 0.9934
# Epoch  4, Train Loss: 0.0355, Acc: 0.9971, Val Loss: 0.0307, Acc: 0.9950
# Epoch  5, Train Loss: 0.0198, Acc: 0.9992, Val Loss: 0.0240, Acc: 0.9967
# Epoch  6, Train Loss: 0.0140, Acc: 0.9983, Val Loss: 0.0234, Acc: 0.9950
# Epoch  7, Train Loss: 0.0098, Acc: 0.9996, Val Loss: 0.0281, Acc: 0.9917
# Epoch  8, Train Loss: 0.0077, Acc: 1.0000, Val Loss: 0.0299, Acc: 0.9917
# Epoch  9, Train Loss: 0.0060, Acc: 1.0000, Val Loss: 0.0248, Acc: 0.9934
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=2e-05, BS=64
# Epoch  1, Train Loss: 1.7053, Acc: 0.4735, Val Loss: 0.9258, Acc: 0.8557
# Epoch  2, Train Loss: 0.6190, Acc: 0.9080, Val Loss: 0.2623, Acc: 0.9635
# Epoch  3, Train Loss: 0.1973, Acc: 0.9772, Val Loss: 0.1063, Acc: 0.9818
# Epoch  4, Train Loss: 0.0907, Acc: 0.9921, Val Loss: 0.0597, Acc: 0.9900
# Epoch  5, Train Loss: 0.0500, Acc: 0.9963, Val Loss: 0.0443, Acc: 0.9917
# Epoch  6, Train Loss: 0.0324, Acc: 0.9975, Val Loss: 0.0363, Acc: 0.9934
# Epoch  7, Train Loss: 0.0235, Acc: 0.9983, Val Loss: 0.0308, Acc: 0.9934
# Epoch  8, Train Loss: 0.0184, Acc: 0.9988, Val Loss: 0.0295, Acc: 0.9934
# Epoch  9, Train Loss: 0.0125, Acc: 1.0000, Val Loss: 0.0282, Acc: 0.9934
# Epoch 10, Train Loss: 0.0105, Acc: 1.0000, Val Loss: 0.0278, Acc: 0.9934
# Epoch 11, Train Loss: 0.0083, Acc: 1.0000, Val Loss: 0.0275, Acc: 0.9934
# Epoch 12, Train Loss: 0.0071, Acc: 1.0000, Val Loss: 0.0272, Acc: 0.9934
# Epoch 13, Train Loss: 0.0064, Acc: 1.0000, Val Loss: 0.0284, Acc: 0.9934
# Epoch 14, Train Loss: 0.0055, Acc: 1.0000, Val Loss: 0.0280, Acc: 0.9934
# Epoch 15, Train Loss: 0.0049, Acc: 1.0000, Val Loss: 0.0285, Acc: 0.9934
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=1e-05, BS=16
# Epoch  1, Train Loss: 1.4297, Acc: 0.5895, Val Loss: 0.5303, Acc: 0.9386
# Epoch  2, Train Loss: 0.3336, Acc: 0.9598, Val Loss: 0.1344, Acc: 0.9751
# Epoch  3, Train Loss: 0.1100, Acc: 0.9905, Val Loss: 0.0640, Acc: 0.9884
# Epoch  4, Train Loss: 0.0551, Acc: 0.9934, Val Loss: 0.0419, Acc: 0.9934
# Epoch  5, Train Loss: 0.0322, Acc: 0.9967, Val Loss: 0.0363, Acc: 0.9934
# Epoch  6, Train Loss: 0.0220, Acc: 0.9983, Val Loss: 0.0327, Acc: 0.9934
# Epoch  7, Train Loss: 0.0156, Acc: 0.9988, Val Loss: 0.0306, Acc: 0.9934
# Epoch  8, Train Loss: 0.0097, Acc: 1.0000, Val Loss: 0.0295, Acc: 0.9934
# Epoch  9, Train Loss: 0.0102, Acc: 0.9988, Val Loss: 0.0303, Acc: 0.9917
# Epoch 10, Train Loss: 0.0064, Acc: 1.0000, Val Loss: 0.0304, Acc: 0.9934
# Epoch 11, Train Loss: 0.0054, Acc: 1.0000, Val Loss: 0.0310, Acc: 0.9934
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
#  Training with LR=1e-05, BS=32
# Epoch  1, Train Loss: 1.7448, Acc: 0.4623, Val Loss: 1.0179, Acc: 0.8474
# Epoch  2, Train Loss: 0.7139, Acc: 0.8803, Val Loss: 0.3463, Acc: 0.9635
# Epoch  3, Train Loss: 0.2706, Acc: 0.9747, Val Loss: 0.1506, Acc: 0.9784
# Epoch  4, Train Loss: 0.1291, Acc: 0.9888, Val Loss: 0.0877, Acc: 0.9867
# Epoch  5, Train Loss: 0.0717, Acc: 0.9963, Val Loss: 0.0580, Acc: 0.9900
# Epoch  6, Train Loss: 0.0481, Acc: 0.9975, Val Loss: 0.0466, Acc: 0.9917
# Epoch  7, Train Loss: 0.0327, Acc: 0.9979, Val Loss: 0.0404, Acc: 0.9917
# Epoch  8, Train Loss: 0.0241, Acc: 0.9988, Val Loss: 0.0360, Acc: 0.9917
# Epoch  9, Train Loss: 0.0184, Acc: 0.9996, Val Loss: 0.0333, Acc: 0.9917
# Epoch 10, Train Loss: 0.0142, Acc: 0.9996, Val Loss: 0.0321, Acc: 0.9917
# Epoch 11, Train Loss: 0.0121, Acc: 0.9996, Val Loss: 0.0326, Acc: 0.9917
# Epoch 12, Train Loss: 0.0117, Acc: 0.9992, Val Loss: 0.0267, Acc: 0.9917
# Epoch 13, Train Loss: 0.0091, Acc: 1.0000, Val Loss: 0.0281, Acc: 0.9917
# Epoch 14, Train Loss: 0.0075, Acc: 1.0000, Val Loss: 0.0282, Acc: 0.9917
# Epoch 15, Train Loss: 0.0066, Acc: 1.0000, Val Loss: 0.0291, Acc: 0.9917
# Early stopping.
#  Final Test Accuracy: 99.34%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      1.00      1.00        90
#      call_contact       1.00      1.00      1.00        32
#      camera_query       1.00      1.00      1.00        28
#       iot_wemo_on       1.00      1.00      1.00        33
# lists_createoradd       0.98      0.98      0.98        61
#             query       0.99      1.00      0.99        68
#      send_message       1.00      1.00      1.00        33
#   transport_query       1.00      0.98      0.99        93
#     weather_query       0.98      0.99      0.99       123
#
#          accuracy                           0.99       603
#         macro avg       1.00      1.00      1.00       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 30.42 seconds
#
# ...
#
#
#  Response Time: 39.43 seconds
#
#  Training with LR=5e-05, BS=32
# Epoch  1, Train Loss: 0.6856, Acc: 0.8210, Val Loss: 0.0722, Acc: 0.9851
# Epoch  2, Train Loss: 0.0460, Acc: 0.9938, Val Loss: 0.0367, Acc: 0.9900
# Epoch  3, Train Loss: 0.0224, Acc: 0.9967, Val Loss: 0.0411, Acc: 0.9884
# Epoch  4, Train Loss: 0.0120, Acc: 0.9988, Val Loss: 0.0282, Acc: 0.9917
# Epoch  5, Train Loss: 0.0050, Acc: 1.0000, Val Loss: 0.0263, Acc: 0.9917
# Epoch  6, Train Loss: 0.0035, Acc: 1.0000, Val Loss: 0.0253, Acc: 0.9917
# Epoch  7, Train Loss: 0.0027, Acc: 1.0000, Val Loss: 0.0243, Acc: 0.9917
# Epoch  8, Train Loss: 0.0085, Acc: 0.9992, Val Loss: 0.0354, Acc: 0.9867
# Epoch  9, Train Loss: 0.0068, Acc: 0.9988, Val Loss: 0.0254, Acc: 0.9917
# Epoch 10, Train Loss: 0.0037, Acc: 0.9996, Val Loss: 0.0289, Acc: 0.9900
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=5e-05, BS=64
# Epoch  1, Train Loss: 1.0283, Acc: 0.7167, Val Loss: 0.1589, Acc: 0.9834
# Epoch  2, Train Loss: 0.0984, Acc: 0.9880, Val Loss: 0.0509, Acc: 0.9851
# Epoch  3, Train Loss: 0.0299, Acc: 0.9963, Val Loss: 0.0481, Acc: 0.9884
# Epoch  4, Train Loss: 0.0187, Acc: 0.9975, Val Loss: 0.0395, Acc: 0.9867
# Epoch  5, Train Loss: 0.0144, Acc: 0.9979, Val Loss: 0.0409, Acc: 0.9867
# Epoch  6, Train Loss: 0.0074, Acc: 0.9996, Val Loss: 0.0432, Acc: 0.9851
# Epoch  7, Train Loss: 0.0080, Acc: 0.9988, Val Loss: 0.0430, Acc: 0.9867
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=2e-05, BS=16
# Epoch  1, Train Loss: 1.0089, Acc: 0.7357, Val Loss: 0.1630, Acc: 0.9768
# Epoch  2, Train Loss: 0.1131, Acc: 0.9851, Val Loss: 0.0567, Acc: 0.9851
# Epoch  3, Train Loss: 0.0393, Acc: 0.9950, Val Loss: 0.0385, Acc: 0.9917
# Epoch  4, Train Loss: 0.0170, Acc: 0.9992, Val Loss: 0.0311, Acc: 0.9884
# Epoch  5, Train Loss: 0.0120, Acc: 0.9992, Val Loss: 0.0275, Acc: 0.9934
# Epoch  6, Train Loss: 0.0069, Acc: 1.0000, Val Loss: 0.0279, Acc: 0.9917
# Epoch  7, Train Loss: 0.0049, Acc: 1.0000, Val Loss: 0.0246, Acc: 0.9917
# Epoch  8, Train Loss: 0.0041, Acc: 1.0000, Val Loss: 0.0244, Acc: 0.9917
# Epoch  9, Train Loss: 0.0033, Acc: 1.0000, Val Loss: 0.0284, Acc: 0.9934
# Epoch 10, Train Loss: 0.0030, Acc: 1.0000, Val Loss: 0.0249, Acc: 0.9917
# Epoch 11, Train Loss: 0.0025, Acc: 1.0000, Val Loss: 0.0249, Acc: 0.9917
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=2e-05, BS=32
# Epoch  1, Train Loss: 1.3360, Acc: 0.6243, Val Loss: 0.4214, Acc: 0.9536
# Epoch  2, Train Loss: 0.2603, Acc: 0.9714, Val Loss: 0.0918, Acc: 0.9834
# Epoch  3, Train Loss: 0.0752, Acc: 0.9946, Val Loss: 0.0507, Acc: 0.9834
# Epoch  4, Train Loss: 0.0398, Acc: 0.9942, Val Loss: 0.0380, Acc: 0.9867
# Epoch  5, Train Loss: 0.0216, Acc: 0.9988, Val Loss: 0.0356, Acc: 0.9867
# Epoch  6, Train Loss: 0.0145, Acc: 1.0000, Val Loss: 0.0316, Acc: 0.9851
# Epoch  7, Train Loss: 0.0104, Acc: 1.0000, Val Loss: 0.0308, Acc: 0.9884
# Epoch  8, Train Loss: 0.0079, Acc: 1.0000, Val Loss: 0.0292, Acc: 0.9884
# Epoch  9, Train Loss: 0.0069, Acc: 0.9992, Val Loss: 0.0306, Acc: 0.9884
# Epoch 10, Train Loss: 0.0094, Acc: 0.9988, Val Loss: 0.0321, Acc: 0.9884
# Epoch 11, Train Loss: 0.0082, Acc: 0.9988, Val Loss: 0.0330, Acc: 0.9867
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=2e-05, BS=64
# Epoch  1, Train Loss: 1.7552, Acc: 0.4424, Val Loss: 0.9077, Acc: 0.8922
# Epoch  2, Train Loss: 0.5962, Acc: 0.9254, Val Loss: 0.2443, Acc: 0.9635
# Epoch  3, Train Loss: 0.2020, Acc: 0.9776, Val Loss: 0.0964, Acc: 0.9900
# Epoch  4, Train Loss: 0.0863, Acc: 0.9934, Val Loss: 0.0590, Acc: 0.9867
# Epoch  5, Train Loss: 0.0523, Acc: 0.9954, Val Loss: 0.0469, Acc: 0.9884
# Epoch  6, Train Loss: 0.0343, Acc: 0.9979, Val Loss: 0.0404, Acc: 0.9884
# Epoch  7, Train Loss: 0.0238, Acc: 0.9983, Val Loss: 0.0375, Acc: 0.9884
# Epoch  8, Train Loss: 0.0175, Acc: 1.0000, Val Loss: 0.0367, Acc: 0.9884
# Epoch  9, Train Loss: 0.0141, Acc: 0.9992, Val Loss: 0.0352, Acc: 0.9884
# Epoch 10, Train Loss: 0.0110, Acc: 0.9996, Val Loss: 0.0333, Acc: 0.9884
# Epoch 11, Train Loss: 0.0100, Acc: 1.0000, Val Loss: 0.0336, Acc: 0.9884
# Epoch 12, Train Loss: 0.0084, Acc: 0.9996, Val Loss: 0.0318, Acc: 0.9884
# Epoch 13, Train Loss: 0.0075, Acc: 1.0000, Val Loss: 0.0332, Acc: 0.9900
# Epoch 14, Train Loss: 0.0063, Acc: 1.0000, Val Loss: 0.0346, Acc: 0.9884
# Epoch 15, Train Loss: 0.0056, Acc: 1.0000, Val Loss: 0.0348, Acc: 0.9900
# Early stopping.
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=1e-05, BS=16
# Epoch  1, Train Loss: 1.5540, Acc: 0.5464, Val Loss: 0.6383, Acc: 0.9436
# Epoch  2, Train Loss: 0.4172, Acc: 0.9544, Val Loss: 0.1607, Acc: 0.9900
# Epoch  3, Train Loss: 0.1401, Acc: 0.9872, Val Loss: 0.0713, Acc: 0.9867
# Epoch  4, Train Loss: 0.0622, Acc: 0.9954, Val Loss: 0.0488, Acc: 0.9884
# Epoch  5, Train Loss: 0.0365, Acc: 0.9979, Val Loss: 0.0398, Acc: 0.9917
# Epoch  6, Train Loss: 0.0254, Acc: 0.9979, Val Loss: 0.0351, Acc: 0.9917
# Epoch  7, Train Loss: 0.0171, Acc: 0.9988, Val Loss: 0.0328, Acc: 0.9900
# Epoch  8, Train Loss: 0.0129, Acc: 0.9992, Val Loss: 0.0334, Acc: 0.9917
# Epoch  9, Train Loss: 0.0104, Acc: 0.9988, Val Loss: 0.0317, Acc: 0.9934
# Epoch 10, Train Loss: 0.0083, Acc: 0.9996, Val Loss: 0.0290, Acc: 0.9917
# Epoch 11, Train Loss: 0.0065, Acc: 1.0000, Val Loss: 0.0322, Acc: 0.9917
# Epoch 12, Train Loss: 0.0058, Acc: 1.0000, Val Loss: 0.0325, Acc: 0.9934
# Epoch 13, Train Loss: 0.0049, Acc: 1.0000, Val Loss: 0.0262, Acc: 0.9950
# Epoch 14, Train Loss: 0.0040, Acc: 1.0000, Val Loss: 0.0261, Acc: 0.9950
# Epoch 15, Train Loss: 0.0036, Acc: 1.0000, Val Loss: 0.0270, Acc: 0.9934
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=1e-05, BS=32
# Epoch  1, Train Loss: 1.7661, Acc: 0.4486, Val Loss: 1.0981, Acc: 0.7977
# Epoch  2, Train Loss: 0.7688, Acc: 0.8811, Val Loss: 0.3537, Acc: 0.9751
# Epoch  3, Train Loss: 0.2832, Acc: 0.9689, Val Loss: 0.1381, Acc: 0.9900
# Epoch  4, Train Loss: 0.1322, Acc: 0.9892, Val Loss: 0.0788, Acc: 0.9884
# Epoch  5, Train Loss: 0.0756, Acc: 0.9950, Val Loss: 0.0606, Acc: 0.9900
# Epoch  6, Train Loss: 0.0503, Acc: 0.9967, Val Loss: 0.0487, Acc: 0.9867
# Epoch  7, Train Loss: 0.0332, Acc: 0.9988, Val Loss: 0.0433, Acc: 0.9900
# Epoch  8, Train Loss: 0.0246, Acc: 0.9988, Val Loss: 0.0404, Acc: 0.9900
# Epoch  9, Train Loss: 0.0194, Acc: 0.9983, Val Loss: 0.0399, Acc: 0.9900
# Epoch 10, Train Loss: 0.0147, Acc: 0.9996, Val Loss: 0.0381, Acc: 0.9900
# Epoch 11, Train Loss: 0.0130, Acc: 0.9992, Val Loss: 0.0350, Acc: 0.9917
# Epoch 12, Train Loss: 0.0110, Acc: 0.9996, Val Loss: 0.0358, Acc: 0.9884
# Epoch 13, Train Loss: 0.0095, Acc: 0.9996, Val Loss: 0.0336, Acc: 0.9884
# Epoch 14, Train Loss: 0.0079, Acc: 1.0000, Val Loss: 0.0326, Acc: 0.9917
# Epoch 15, Train Loss: 0.0069, Acc: 1.0000, Val Loss: 0.0319, Acc: 0.9900
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
#
#  Training with LR=1e-05, BS=64
# Epoch  1, Train Loss: 2.0424, Acc: 0.3065, Val Loss: 1.5844, Acc: 0.5307
# Epoch  2, Train Loss: 1.3118, Acc: 0.6823, Val Loss: 0.8382, Acc: 0.8955
# Epoch  3, Train Loss: 0.6925, Acc: 0.9147, Val Loss: 0.3978, Acc: 0.9635
# Epoch  4, Train Loss: 0.3695, Acc: 0.9635, Val Loss: 0.2088, Acc: 0.9784
# Epoch  5, Train Loss: 0.2115, Acc: 0.9814, Val Loss: 0.1264, Acc: 0.9851
# Epoch  6, Train Loss: 0.1307, Acc: 0.9901, Val Loss: 0.0876, Acc: 0.9900
# Epoch  7, Train Loss: 0.0879, Acc: 0.9930, Val Loss: 0.0672, Acc: 0.9884
# Epoch  8, Train Loss: 0.0646, Acc: 0.9946, Val Loss: 0.0569, Acc: 0.9900
# Epoch  9, Train Loss: 0.0486, Acc: 0.9963, Val Loss: 0.0511, Acc: 0.9867
# Epoch 10, Train Loss: 0.0395, Acc: 0.9967, Val Loss: 0.0469, Acc: 0.9867
# Epoch 11, Train Loss: 0.0333, Acc: 0.9971, Val Loss: 0.0432, Acc: 0.9884
# Epoch 12, Train Loss: 0.0252, Acc: 0.9988, Val Loss: 0.0415, Acc: 0.9867
# Epoch 13, Train Loss: 0.0218, Acc: 0.9988, Val Loss: 0.0417, Acc: 0.9867
# Epoch 14, Train Loss: 0.0181, Acc: 0.9996, Val Loss: 0.0409, Acc: 0.9884
# Epoch 15, Train Loss: 0.0168, Acc: 0.9988, Val Loss: 0.0390, Acc: 0.9867
#  Final Test Accuracy: 99.17%
#
#  Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        42
#      calendar_set       1.00      0.99      0.99        90
#      call_contact       1.00      0.97      0.98        32
#      camera_query       0.94      1.00      0.97        29
#       iot_wemo_on       1.00      0.97      0.99        34
# lists_createoradd       0.98      0.98      0.98        62
#             query       1.00      1.00      1.00        68
#      send_message       0.97      1.00      0.98        32
#   transport_query       1.00      0.99      0.99        92
#     weather_query       0.99      1.00      1.00       122
#
#          accuracy                           0.99       603
#         macro avg       0.99      0.99      0.99       603
#      weighted avg       0.99      0.99      0.99       603
#
#
#  Response Time: 35.81 seconds
# /tmp/ipykernel_1039963/1756765122.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load(best_model_path))
# 📊 Cross-Validation Performance Summary:
# Mean Macro F1: 0.9927 ± 0.0025
# Mean Accuracy: 0.9930 ± 0.0014

# %% [markdown]
# ביצוע הערכה סופית (Final Evaluation) של המודל הכי טוב שהתקבל מה־Cross Validation רק על משפטי הקשישים.
#
# שמירת True Positives של המודל במקרים שסירי נכשלה (label == 0)
#
# שמירה לקובץ CSV של המשפטים שהמודל זיהה נכון וסירי לא

# %%
elderly_df = elderly_with_label

# Now apply it to the elderly data:
elderly_df["intent_num"] = le.transform(elderly_df["intent"])

# Create mapping from label index to intent name (if not already defined)
map_intent = dict(zip(le.transform(le.classes_), le.classes_))

# %%
# Prepare input + labels
texts = elderly_df["transcript_hebrew"].tolist()
labels = elderly_df["intent_num"].tolist()

# Tokenize
encoded = tokenizer(
    texts,
    padding=True,
    truncation=True,
    max_length=128,
    return_tensors='pt'
)

# Create DataLoader
test_dataset = TensorDataset(
    encoded["input_ids"].clone().detach(),
    encoded["attention_mask"].clone().detach(),
    torch.tensor(labels, dtype=torch.long)
)
test_loader = DataLoader(test_dataset, batch_size=best_batch_size_overall, shuffle=False)

# Load model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BertForIntentClassification(copy.deepcopy(base_model), num_classes=len(map_intent)).to(device)
model.load_state_dict(torch.load(best_model_path_overall))
model.eval()

# Predict + Evaluate
all_preds, all_labels = [], []
true_positive_rows = []

with torch.no_grad():
    for i, batch in enumerate(test_loader):
        input_ids, attention_mask, y = [b.to(device) for b in batch]
        outputs = model(input_ids, attention_mask)
        preds = torch.argmax(outputs, dim=1)

        for j in range(len(preds)):
            pred = preds[j].item()
            true = y[j].item()
            all_preds.append(pred)
            all_labels.append(true)

            row_index = i * best_batch_size_overall + j
            if row_index < len(elderly_df):
                row = elderly_df.iloc[row_index]
                if pred == true and row["label"] == 0:  # Siri failed
                    row_with_pred = row.copy()
                    row_with_pred["predicted_intent"] = map_intent[pred]
                    true_positive_rows.append(row_with_pred)

# Evaluation
acc = accuracy_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average="macro")
intent_names = [map_intent[i] for i in sorted(set(all_labels + all_preds))]

print(f"\n🧓 Final Evaluation on Elderly Data:")
print(f"Accuracy: {acc * 100:.2f}%")
print(f"Macro F1: {f1:.4f}")
print("\nClassification Report:")
print(classification_report(all_labels, all_preds, target_names=intent_names))
# Out:
# /tmp/ipykernel_1039963/425248677.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path_overall))
# 🧓 Final Evaluation on Elderly Data:
# Accuracy: 94.94%
# Macro F1: 0.9574
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#         alarm_set       1.00      1.00      1.00        29
#      calendar_set       1.00      1.00      1.00        29
#      call_contact       0.95      0.78      0.86        27
#      camera_query       1.00      1.00      1.00        15
#       iot_wemo_on       1.00      1.00      1.00         9
# lists_createoradd       0.96      1.00      0.98        22
#             query       1.00      0.76      0.86        21
#      send_message       0.95      0.95      0.95        19
#   transport_query       0.86      1.00      0.93        57
#     weather_query       1.00      1.00      1.00         9
#
#          accuracy                           0.95       237
#         macro avg       0.97      0.95      0.96       237
#      weighted avg       0.95      0.95      0.95       237

# %% [markdown]
# שמירת הפקודות שזוהו במודל שלנו אך נכשלו בניסוי על ידי סירי לטובת ניסוח מחדש

# %%
df_tp = pd.DataFrame(true_positive_rows)
df_siri_failed = elderly_df[elderly_df["label"] == 0]
matched_df = df_siri_failed[df_siri_failed["transcript_hebrew"].isin(df_tp["transcript_hebrew"])]
matched_df.to_csv("siri_failed_model_succeeded.csv", index=False, encoding="utf-8-sig")
